# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
Houses=pd.read_csv('California_Houses.csv')

# %%
Houses
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
Houses.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
Houses.shape
# Out:
# (20640, 10)

# %%
Houses['total_bedrooms'].isna().sum()
# Out:
# 207

# %%
# if we try to push any value using fillna  but  how can we fill not have any proper way to fill so remmove those rows
Houses.dropna(inplace=True)
Houses['total_bedrooms'].isna().sum()
# Out:
# 0

# %%
Houses.shape
# Out:
# (20433, 10)

# %%
# 20640-207
Houses['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
Houses['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: count, dtype: int64

# %%
Houses=pd.get_dummies(data=Houses)
Houses
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
Houses.dtypes
# Out:
# longitude                     float64
# latitude                      float64
# housing_median_age            float64
# total_rooms                   float64
# total_bedrooms                float64
# population                    float64
# households                    float64
# median_income                 float64
# median_house_value            float64
# ocean_proximity_<1H OCEAN        bool
# ocean_proximity_INLAND           bool
# ocean_proximity_ISLAND           bool
# ocean_proximity_NEAR BAY         bool
# ocean_proximity_NEAR OCEAN       bool
# dtype: object

# %%
Houses.corr()
# Out:
#                             longitude  latitude  housing_median_age  \
# longitude                    1.000000 -0.924616           -0.109357
# latitude                    -0.924616  1.000000            0.011899
# housing_median_age          -0.109357  0.011899            1.000000
# total_rooms                  0.045480 -0.036667           -0.360628
# total_bedrooms               0.069608 -0.066983           -0.320451
# population                   0.100270 -0.108997           -0.295787
# households                   0.056513 -0.071774           -0.302768
# median_income               -0.015550 -0.079626           -0.118278
# median_house_value          -0.045398 -0.144638            0.106432
# ocean_proximity_<1H OCEAN    0.320831 -0.446928            0.045553
# ocean_proximity_INLAND      -0.055337  0.351084           -0.236968
# ocean_proximity_ISLAND       0.009501 -0.016662            0.017105
# ocean_proximity_NEAR BAY    -0.474714  0.358785            0.256149
# ...

# %%
sns.heatmap(data=Houses.corr())
# Out:
# <Axes: >

# %%
Houses.columns[1]
# Out:
# 'latitude'

# %%
Houses.shape
# Out:
# (20433, 14)

# %%
df=Houses[['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income',
        'ocean_proximity_<1H OCEAN',
       'ocean_proximity_INLAND', 'ocean_proximity_ISLAND',
       'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN']]
plt.figure(figsize=(50,50))
for i in range(len(df.columns)):
    plt.subplot(14,5,i+1)
    sns.regplot(data=df,x=df.columns[i],y=Houses['median_house_value'])
plt.show()

# %%
plt.figure(figsize=(50,50))
for i in range(len(df.columns)):
    plt.subplot(14,5,i+1)
    sns.histplot(data=df,x=df.columns[i],y=Houses['median_house_value'])
plt.show()
# Out:
# C:\Users\dhruv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dhruv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dhruv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df=Houses[['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income',
        'ocean_proximity_<1H OCEAN','median_house_value',
       'ocean_proximity_INLAND', 'ocean_proximity_ISLAND',
       'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN']]
plt.figure(figsize=(25,50))
for i in range(len(df.columns)):
    plt.subplot(7,2,i+1)
    if df.columns[i]=='median_house_value':
        continue
    
    sns.regplot(data=df,x=df.columns[i],y='median_house_value')
plt.tight_layout()
plt.show()
