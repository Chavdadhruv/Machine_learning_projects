# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
ads=pd.read_csv('Advertising.csv')
ads
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
ads.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
ads.values
# Out:
# array([[230.1,  37.8,  69.2,  22.1],
#        [ 44.5,  39.3,  45.1,  10.4],
#        [ 17.2,  45.9,  69.3,  12. ],
#        [151.5,  41.3,  58.5,  16.5],
#        [180.8,  10.8,  58.4,  17.9],
#        [  8.7,  48.9,  75. ,   7.2],
#        [ 57.5,  32.8,  23.5,  11.8],
#        [120.2,  19.6,  11.6,  13.2],
#        [  8.6,   2.1,   1. ,   4.8],
#        [199.8,   2.6,  21.2,  15.6],
#        [ 66.1,   5.8,  24.2,  12.6],
#        [214.7,  24. ,   4. ,  17.4],
#        [ 23.8,  35.1,  65.9,   9.2],
#        [ 97.5,   7.6,   7.2,  13.7],
#        [204.1,  32.9,  46. ,  19. ],
#        [195.4,  47.7,  52.9,  22.4],
#        [ 67.8,  36.6, 114. ,  12.5],
#        [281.4,  39.6,  55.8,  24.4],
#        [ 69.2,  20.5,  18.3,  11.3],
#        [147.3,  23.9,  19.1,  14.6],
#        [218.4,  27.7,  53.4,  18. ],
#        [237.4,   5.1,  23.5,  17.5],
#        [ 13.2,  15.9,  49.6,   5.6],
#        [228.3,  16.9,  26.2,  20.5],
#        [ 62.3,  12.6,  18.3,   9.7],
# ...

# %%
ads.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
ads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
plt.scatter(data=ads,x='TV',y='Sales',label='TV')
plt.scatter(data=ads,x='Radio',y='Sales',label='Radio')
plt.scatter(data=ads,x='Newspaper',y='Sales',label='Newspaper')
plt.legend()
plt.show()

# %%
# LinearRegression
x=ads.loc[:,['TV']]
y=ads.loc[:,['Sales']]

# %%
print(x," ** ",y)
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]  **       Sales
# 0     22.1
# 1     10.4
# 2     12.0
# 3     16.5
# 4     17.9
# ..     ...
# 195    7.6
# 196   14.0
# 197   14.8
# 198   25.5
# 199   18.4
#
# [200 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=2,test_size=0.3)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.7651379928818158
# 6.041440872775862

# %%
plt.scatter(data=ads,x='TV',y='Sales',label='TV')
plt.legend()
plt.show()

# %%
plt.scatter(x=x_test,y=y_pred,label='TV')
plt.legend()
plt.show()

# %%
# so done our liner regression process for tv

# %%
sns.regplot(data=ads,x='TV',y='Sales',label='TV')
sns.regplot(data=ads,x='Radio',y='Sales',label='Radio')
sns.regplot(data=ads,x='Newspaper',y='Sales',label='Newspaper')
plt.legend()
plt.show()

# %%
# now for     Newspaper  
# LinearRegression
x1=ads.loc[:,['Newspaper']]
y1=ads.loc[:,['Sales']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y1,random_state=2,test_size=0.3)
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# this is not possible to get -0.037 so we can use
# Out:
# -0.03791609392923667
# 26.69869337027593

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=4)
x_poly=poly.fit_transform(x1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_poly,y,test_size=0.2,random_state=20)

# %%
l=LinearRegression()
l.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=l.predict(x_test)
y_pred
# Out:
# array([[14.98668088],
#        [13.76715236],
#        [14.53491909],
#        [13.80401967],
#        [14.84469056],
#        [17.25078876],
#        [14.78391647],
#        [14.3927069 ],
#        [13.67046833],
#        [13.80628022],
#        [14.22542912],
#        [13.78360496],
#        [13.67114619],
#        [13.71911412],
#        [14.63207671],
#        [15.55191189],
#        [14.80536853],
#        [13.6743671 ],
#        [16.54906687],
#        [14.40688867],
#        [13.68683314],
#        [14.06107429],
#        [16.65640749],
#        [15.85006631],
#        [13.67641185],
#        [14.69643497],
#        [14.30593932],
#        [16.57074476],
#        [17.96223283],
#        [13.73227371],
#        [14.50204441],
#        [15.74779426],
#        [15.73105238],
#        [13.67350307],
#        [17.95652819],
#        [17.78267704],
#        [13.69281948],
#        [14.83947467],
#        [13.70818356],
#        [15.55828004]])

# %%
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# -0.02300207743169569
# 38.21628221285287

# %%
# so this polynomialmodel is not usefull for this now we user multiple LinearRegression


# now for     multiple  
# LinearRegression
x1=ads.drop(columns=['Sales'])
y1=ads.loc[:,['Sales']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y1,random_state=2,test_size=0.3)
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# this is not possible to get -0.037 so we can use
# Out:
# 0.8669425938331328
# 3.422684076942014

# %%
# before
sns.regplot(x=x,y=y)
plt.show()

# %%
sns.regplot(x=y_test,y=y_pred)
plt.show()

# %%
df=ads.columns

# %%
dfs=ads[['TV', 'Radio', 'Newspaper']]
plt.figure(figsize=(10,10))
for i in range(len(dfs.columns)):
    plt.subplot(3,3,i+1)
    sns.histplot(data=ads,x=ads.columns[i],kde=True)
plt.show()
# Out:
# C:\Users\dhruv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dhruv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dhruv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dfs=ads[['TV', 'Radio', 'Newspaper']]
for i in range(len(dfs.columns)):
    plt.subplot(3,3,i+1)
    sns.regplot(data=ads,x=ads.columns[i],y=ads['Sales'])
plt.show()

# %%
# thank you
